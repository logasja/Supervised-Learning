# %%
# From https://www.springboard.com/blog/beginners-guide-neural-network-in-python-scikit-learn-0-18/ 
import pandas as pd
import numpy as np
import itertools
from matplotlib import pyplot as plt
from matplotlib.colors import ListedColormap
from sklearn import svm
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split, ShuffleSplit, learning_curve, GridSearchCV
from sklearn.metrics import recall_score, classification_report, confusion_matrix
perform = pd.read_csv('../datasets/student_perform.csv')
perform.head()
# Out:
#   gender NationalITy PlaceofBirth     StageID GradeID SectionID Topic  \
# 0      M          KW       KuwaIT  lowerlevel    G-04         A    IT
# 1      M          KW       KuwaIT  lowerlevel    G-04         A    IT
# 2      M          KW       KuwaIT  lowerlevel    G-04         A    IT
# 3      M          KW       KuwaIT  lowerlevel    G-04         A    IT
# 4      M          KW       KuwaIT  lowerlevel    G-04         A    IT
#
#   Semester Relation  raisedhands  VisITedResources  AnnouncementsView  \
# 0        F   Father           15                16                  2
# 1        F   Father           20                20                  3
# 2        F   Father           10                 7                  0
# 3        F   Father           30                25                  5
# 4        F   Father           40                50                 12
#
#    Discussion ParentAnsweringSurvey ParentschoolSatisfaction  \
# 0          20                   Yes                     Good
# 1          25                   Yes                     Good
# 2          30                    No                      Bad
# 3          35                    No                      Bad
# 4          50                    No                      Bad
#
#   StudentAbsenceDays Class
# 0            Under-7     M
# 1            Under-7     M
# 2            Above-7     L
# 3            Above-7     L
# 4            Above-7     M

# %% [markdown]
# # Learning Curve Definition

# %%
# Courtesy of http://scikit-learn.org/stable/auto_examples/model_selection/plot_learning_curve.html

def plot_learning_curve(estimator, title, X, y, ylim=None, cv=None,
                        n_jobs=1, train_sizes=np.linspace(.1, 1.0, 5)):
    """
    Generate a simple plot of the test and training learning curve.

    Parameters
    ----------
    estimator : object type that implements the "fit" and "predict" methods
        An object of that type which is cloned for each validation.

    title : string
        Title for the chart.

    X : array-like, shape (n_samples, n_features)
        Training vector, where n_samples is the number of samples and
        n_features is the number of features.

    y : array-like, shape (n_samples) or (n_samples, n_features), optional
        Target relative to X for classification or regression;
        None for unsupervised learning.

    ylim : tuple, shape (ymin, ymax), optional
        Defines minimum and maximum yvalues plotted.

    cv : int, cross-validation generator or an iterable, optional
        Determines the cross-validation splitting strategy.
        Possible inputs for cv are:
          - None, to use the default 3-fold cross-validation,
          - integer, to specify the number of folds.
          - An object to be used as a cross-validation generator.
          - An iterable yielding train/test splits.

        For integer/None inputs, if ``y`` is binary or multiclass,
        :class:`StratifiedKFold` used. If the estimator is not a classifier
        or if ``y`` is neither binary nor multiclass, :class:`KFold` is used.

        Refer :ref:`User Guide <cross_validation>` for the various
        cross-validators that can be used here.

    n_jobs : integer, optional
        Number of jobs to run in parallel (default 1).
    """
    plt.figure()
    plt.title(title)
    if ylim is not None:
        plt.ylim(*ylim)
    plt.xlabel("Training examples")
    plt.ylabel("Score")
    train_sizes, train_scores, test_scores = learning_curve(
        estimator, X, y, cv=cv, n_jobs=n_jobs, train_sizes=train_sizes)
    train_scores_mean = np.mean(train_scores, axis=1)
    train_scores_std = np.std(train_scores, axis=1)
    test_scores_mean = np.mean(test_scores, axis=1)
    test_scores_std = np.std(test_scores, axis=1)
    plt.grid()

    plt.fill_between(train_sizes, train_scores_mean - train_scores_std,
                     train_scores_mean + train_scores_std, alpha=0.1,
                     color="r")
    plt.fill_between(train_sizes, test_scores_mean - test_scores_std,
                     test_scores_mean + test_scores_std, alpha=0.1, color="g")
    plt.plot(train_sizes, train_scores_mean, 'o-', color="r",
             label="Training score")
    plt.plot(train_sizes, test_scores_mean, 'o-', color="g",
             label="Cross-validation score")

    plt.legend(loc="best")
    return plt

# %% [markdown]
# # Confusion Matrix Definition

# %%
def plot_confusion_matrix(cm, classes,
                          normalize=False,
                          title='Confusion matrix',
                          cmap=plt.cm.Blues):
    """
    This function prints and plots the confusion matrix.
    Normalization can be applied by setting `normalize=True`.
    """
    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
        print("Normalized confusion matrix")
    else:
        print('Confusion matrix, without normalization')

    print(cm)

    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=45)
    plt.yticks(tick_marks, classes)

    fmt = '.2f' if normalize else 'd'
    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, format(cm[i, j], fmt),
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")

    plt.tight_layout()
    plt.ylabel('True label')
    plt.xlabel('Predicted label')

# %% [markdown]
# # Data

# %%
dicts = {}
for column in perform.columns:
    if perform[column].dtypes == object:
        perform[column], dicts[column] = pd.factorize(perform[column])
perform.describe().transpose()
# Out:
#                           count       mean        std  min    25%   50%   75%  \
# gender                    480.0   0.364583   0.481815  0.0   0.00   0.0   1.0
# NationalITy               480.0   3.858333   3.848478  0.0   0.00   5.0   5.0
# PlaceofBirth              480.0   3.510417   3.505423  0.0   0.00   4.5   5.0
# StageID                   480.0   0.654167   0.603732  0.0   0.00   1.0   1.0
# GradeID                   480.0   4.120833   3.560099  0.0   1.00   2.0   9.0
# SectionID                 480.0   0.472917   0.612411  0.0   0.00   0.0   1.0
# Topic                     480.0   4.402083   3.455472  0.0   2.00   4.0   7.0
# Semester                  480.0   0.489583   0.500413  0.0   0.00   0.0   1.0
# Relation                  480.0   0.410417   0.492423  0.0   0.00   0.0   1.0
# raisedhands               480.0  46.775000  30.779223  0.0  15.75  50.0  75.0
# VisITedResources          480.0  54.797917  33.080007  0.0  20.00  65.0  84.0
# AnnouncementsView         480.0  37.918750  26.611244  0.0  14.00  33.0  58.0
# Discussion                480.0  43.283333  27.637735  1.0  20.00  39.0  70.0
# ParentAnsweringSurvey     480.0   0.437500   0.496596  0.0   0.00   0.0   1.0
# ParentschoolSatisfaction  480.0   0.391667   0.488632  0.0   0.00   0.0   1.0
# StudentAbsenceDays        480.0   0.397917   0.489979  0.0   0.00   0.0   1.0
# Class                     480.0   0.856250   0.846312  0.0   0.00   1.0   2.0
#
#                             max
# gender                      1.0
# NationalITy                13.0
# PlaceofBirth               13.0
# StageID                     2.0
# GradeID                     9.0
# SectionID                   2.0
# Topic                      11.0
# Semester                    1.0
# Relation                    1.0
# raisedhands               100.0
# VisITedResources           99.0
# AnnouncementsView          98.0
# Discussion                 99.0
# ParentAnsweringSurvey       1.0
# ParentschoolSatisfaction    1.0
# StudentAbsenceDays          1.0
# Class                       2.0

# %%
X = perform.drop('Class', axis=1).values
y = perform['Class'].values

# %% [markdown]
# # Data Preprocessing

# %%
scaler = StandardScaler()

# %%
# Fit to training data
scaler.fit(X)
X = scaler.transform(X)
# Out:
# /home/rocket/anaconda2/lib/python2.7/site-packages/sklearn/utils/validation.py:475: DataConversionWarning: Data with input dtype int64 was converted to float64 by StandardScaler.
#   warnings.warn(msg, DataConversionWarning)

# %% [markdown]
# # Train Test Split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=.4, random_state=42)

# %% [markdown]
# # Default Model

# %%
clf = svm.SVC()
clf.fit(X_train, y_train)
print clf.score(X_test, y_test)
# Out:
# 0.734375

# %%
y_pred = clf.predict(X_test)
cnf_matrix = confusion_matrix(y_test, y_pred)

plt.figure()
plot_confusion_matrix(cnf_matrix, classes=dicts['Class'], title='Confusion Matrix MLP Default')
plt.show()
plt.clf()
# Out:
# Confusion matrix, without normalization
# [[68 12 10]
#  [ 9 44  0]
#  [20  0 29]]

# %%
#     Plot learning curve
cv = ShuffleSplit(n_splits=10, test_size=0.2, random_state=0)
clf = svm.SVC()

plot_learning_curve(clf, "Default", X, y, ylim=None, cv=cv, n_jobs=4).show()

# %% [markdown]
# # RBF Kernel Grid Search

# %%
scores = ['accuracy', 'precision_macro', 'recall_macro']

tuned_parameters = [{'gamma': [1, 1e-2, 1e-3, 1e-4],
                     'C': [1, 10, 100]}]

for score in scores:
    plt.clf()
    print("# Tuning hyper-parameters for %s" % score)

    clf = GridSearchCV(svm.SVC(kernel='rbf'), tuned_parameters, cv=5, verbose=0, scoring=score, n_jobs=4)
    clf.fit(X, y)

    plot_learning_curve(clf, score, X, y, ylim=None, cv=cv, n_jobs=4).show()

    print("Best parameters set found on development set:")
    print(clf.best_params_)
    print("Grid scores on development set:")
    means = clf.cv_results_['mean_test_score']
    stds = clf.cv_results_['std_test_score']
    for mean, std, params in zip(means, stds, clf.cv_results_['params']):
        print("%0.3f (+/-%0.03f) for %r"
              % (mean, std * 2, params))
    print

    print("Detailed classification report:")
    print
    print("The model is trained on the full development set.")
    print("The scores are computed on the full evaluation set.")
    print
    y_true, y_pred = y, clf.predict(X)
    print(classification_report(y_true, y_pred))
    print
# Out:
# # Tuning hyper-parameters for accuracy
# /home/rocket/anaconda2/lib/python2.7/site-packages/sklearn/externals/joblib/parallel.py:547: UserWarning: Multiprocessing-backed parallel loops cannot be nested, setting n_jobs=1
#   **self._backend_args)
# /home/rocket/anaconda2/lib/python2.7/site-packages/sklearn/externals/joblib/parallel.py:547: UserWarning: Multiprocessing-backed parallel loops cannot be nested, setting n_jobs=1
#   **self._backend_args)
# /home/rocket/anaconda2/lib/python2.7/site-packages/sklearn/externals/joblib/parallel.py:547: UserWarning: Multiprocessing-backed parallel loops cannot be nested, setting n_jobs=1
#   **self._backend_args)
# /home/rocket/anaconda2/lib/python2.7/site-packages/sklearn/externals/joblib/parallel.py:547: UserWarning: Multiprocessing-backed parallel loops cannot be nested, setting n_jobs=1
#   **self._backend_args)
# Best parameters set found on development set:
# {'C': 100, 'gamma': 0.0001}
# Grid scores on development set:
# 0.448 (+/-0.025) for {'C': 1, 'gamma': 1}
# 0.683 (+/-0.031) for {'C': 1, 'gamma': 0.01}
# 0.558 (+/-0.084) for {'C': 1, 'gamma': 0.001}
# 0.440 (+/-0.007) for {'C': 1, 'gamma': 0.0001}
# 0.452 (+/-0.050) for {'C': 10, 'gamma': 1}
# 0.665 (+/-0.073) for {'C': 10, 'gamma': 0.01}
# 0.694 (+/-0.043) for {'C': 10, 'gamma': 0.001}
# 0.567 (+/-0.076) for {'C': 10, 'gamma': 0.0001}
# 0.452 (+/-0.050) for {'C': 100, 'gamma': 1}
# 0.679 (+/-0.085) for {'C': 100, 'gamma': 0.01}
# 0.681 (+/-0.082) for {'C': 100, 'gamma': 0.001}
# 0.696 (+/-0.047) for {'C': 100, 'gamma': 0.0001}
#
# Detailed classification report:
#
# The model is trained on the full development set.
# The scores are computed on the full evaluation set.
#
#              precision    recall  f1-score   support
#
#           0       0.75      0.76      0.75       211
#           1       0.85      0.87      0.86       127
#           2       0.76      0.73      0.75       142
#
# avg / total       0.78      0.78      0.78       480
#
#
# # Tuning hyper-parameters for precision_macro
# /home/rocket/anaconda2/lib/python2.7/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /home/rocket/anaconda2/lib/python2.7/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /home/rocket/anaconda2/lib/python2.7/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /home/rocket/anaconda2/lib/python2.7/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /home/rocket/anaconda2/lib/python2.7/site-packages/sklearn/externals/joblib/parallel.py:547: UserWarning: Multiprocessing-backed parallel loops cannot be nested, setting n_jobs=1
#   **self._backend_args)
# /home/rocket/anaconda2/lib/python2.7/site-packages/sklearn/externals/joblib/parallel.py:547: UserWarning: Multiprocessing-backed parallel loops cannot be nested, setting n_jobs=1
#   **self._backend_args)
# /home/rocket/anaconda2/lib/python2.7/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /home/rocket/anaconda2/lib/python2.7/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /home/rocket/anaconda2/lib/python2.7/site-packages/sklearn/externals/joblib/parallel.py:547: UserWarning: Multiprocessing-backed parallel loops cannot be nested, setting n_jobs=1
#   **self._backend_args)
# /home/rocket/anaconda2/lib/python2.7/site-packages/sklearn/externals/joblib/parallel.py:547: UserWarning: Multiprocessing-backed parallel loops cannot be nested, setting n_jobs=1
#   **self._backend_args)
# /home/rocket/anaconda2/lib/python2.7/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /home/rocket/anaconda2/lib/python2.7/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# Best parameters set found on development set:
# {'C': 100, 'gamma': 0.0001}
# Grid scores on development set:
# 0.444 (+/-0.616) for {'C': 1, 'gamma': 1}
# 0.708 (+/-0.017) for {'C': 1, 'gamma': 0.01}
# 0.518 (+/-0.319) for {'C': 1, 'gamma': 0.001}
# 0.147 (+/-0.002) for {'C': 1, 'gamma': 0.0001}
# 0.513 (+/-0.542) for {'C': 10, 'gamma': 1}
# 0.694 (+/-0.069) for {'C': 10, 'gamma': 0.01}
# 0.714 (+/-0.026) for {'C': 10, 'gamma': 0.001}
# 0.521 (+/-0.321) for {'C': 10, 'gamma': 0.0001}
# 0.513 (+/-0.542) for {'C': 100, 'gamma': 1}
# 0.712 (+/-0.083) for {'C': 100, 'gamma': 0.01}
# 0.703 (+/-0.080) for {'C': 100, 'gamma': 0.001}
# 0.715 (+/-0.028) for {'C': 100, 'gamma': 0.0001}
#
# Detailed classification report:
#
# The model is trained on the full development set.
# The scores are computed on the full evaluation set.
#
#              precision    recall  f1-score   support
#
#           0       0.75      0.76      0.75       211
#           1       0.85      0.87      0.86       127
#           2       0.76      0.73      0.75       142
#
# avg / total       0.78      0.78      0.78       480
#
#
# # Tuning hyper-parameters for recall_macro
# /home/rocket/anaconda2/lib/python2.7/site-packages/sklearn/externals/joblib/parallel.py:547: UserWarning: Multiprocessing-backed parallel loops cannot be nested, setting n_jobs=1
#   **self._backend_args)
# /home/rocket/anaconda2/lib/python2.7/site-packages/sklearn/externals/joblib/parallel.py:547: UserWarning: Multiprocessing-backed parallel loops cannot be nested, setting n_jobs=1
#   **self._backend_args)
# /home/rocket/anaconda2/lib/python2.7/site-packages/sklearn/externals/joblib/parallel.py:547: UserWarning: Multiprocessing-backed parallel loops cannot be nested, setting n_jobs=1
#   **self._backend_args)
# /home/rocket/anaconda2/lib/python2.7/site-packages/sklearn/externals/joblib/parallel.py:547: UserWarning: Multiprocessing-backed parallel loops cannot be nested, setting n_jobs=1
#   **self._backend_args)
# Best parameters set found on development set:
# {'C': 100, 'gamma': 0.0001}
# Grid scores on development set:
# 0.345 (+/-0.023) for {'C': 1, 'gamma': 1}
# 0.698 (+/-0.038) for {'C': 1, 'gamma': 0.01}
# 0.501 (+/-0.121) for {'C': 1, 'gamma': 0.001}
# 0.333 (+/-0.000) for {'C': 1, 'gamma': 0.0001}
# 0.352 (+/-0.047) for {'C': 10, 'gamma': 1}
# 0.685 (+/-0.089) for {'C': 10, 'gamma': 0.01}
# 0.712 (+/-0.034) for {'C': 10, 'gamma': 0.001}
# 0.511 (+/-0.105) for {'C': 10, 'gamma': 0.0001}
# 0.352 (+/-0.047) for {'C': 100, 'gamma': 1}
# 0.698 (+/-0.103) for {'C': 100, 'gamma': 0.01}
# 0.696 (+/-0.107) for {'C': 100, 'gamma': 0.001}
# 0.715 (+/-0.044) for {'C': 100, 'gamma': 0.0001}
#
# Detailed classification report:
#
# The model is trained on the full development set.
# The scores are computed on the full evaluation set.
#
#              precision    recall  f1-score   support
#
#           0       0.75      0.76      0.75       211
#           1       0.85      0.87      0.86       127
#           2       0.76      0.73      0.75       142
#
# avg / total       0.78      0.78      0.78       480

# %% [markdown]
# # Linear Kernel Grid Search

# %%
tuned_parameters = [{'C': [1, 10, 100]}]

for score in scores:
    plt.clf()
    print("# Tuning hyper-parameters for %s" % score)

    clf = GridSearchCV(svm.SVC(kernel='linear'), tuned_parameters, cv=5, verbose=0, scoring=score, n_jobs=4)
    clf.fit(X, y)

    plot_learning_curve(clf, score, X, y, ylim=None, cv=cv, n_jobs=4).show()

    print("Best parameters set found on development set:")
    print(clf.best_params_)
    print("Grid scores on development set:")
    means = clf.cv_results_['mean_test_score']
    stds = clf.cv_results_['std_test_score']
    for mean, std, params in zip(means, stds, clf.cv_results_['params']):
        print("%0.3f (+/-%0.03f) for %r"
              % (mean, std * 2, params))
    print

    print("Detailed classification report:")
    print
    print("The model is trained on the full development set.")
    print("The scores are computed on the full evaluation set.")
    print
    y_true, y_pred = y, clf.predict(X)
    print(classification_report(y_true, y_pred))
    print
# Out:
# # Tuning hyper-parameters for accuracy
# /home/rocket/anaconda2/lib/python2.7/site-packages/sklearn/externals/joblib/parallel.py:547: UserWarning: Multiprocessing-backed parallel loops cannot be nested, setting n_jobs=1
#   **self._backend_args)
# /home/rocket/anaconda2/lib/python2.7/site-packages/sklearn/externals/joblib/parallel.py:547: UserWarning: Multiprocessing-backed parallel loops cannot be nested, setting n_jobs=1
#   **self._backend_args)
# /home/rocket/anaconda2/lib/python2.7/site-packages/sklearn/externals/joblib/parallel.py:547: UserWarning: Multiprocessing-backed parallel loops cannot be nested, setting n_jobs=1
#   **self._backend_args)
# /home/rocket/anaconda2/lib/python2.7/site-packages/sklearn/externals/joblib/parallel.py:547: UserWarning: Multiprocessing-backed parallel loops cannot be nested, setting n_jobs=1
#   **self._backend_args)
# Best parameters set found on development set:
# {'C': 1}
# Grid scores on development set:
# 0.683 (+/-0.063) for {'C': 1}
# 0.681 (+/-0.050) for {'C': 10}
# 0.679 (+/-0.048) for {'C': 100}
#
# Detailed classification report:
#
# The model is trained on the full development set.
# The scores are computed on the full evaluation set.
#
#              precision    recall  f1-score   support
#
#           0       0.78      0.76      0.77       211
#           1       0.88      0.88      0.88       127
#           2       0.76      0.78      0.77       142
#
# avg / total       0.80      0.80      0.80       480
#
#
# # Tuning hyper-parameters for precision_macro
# /home/rocket/anaconda2/lib/python2.7/site-packages/sklearn/externals/joblib/parallel.py:547: UserWarning: Multiprocessing-backed parallel loops cannot be nested, setting n_jobs=1
#   **self._backend_args)
# /home/rocket/anaconda2/lib/python2.7/site-packages/sklearn/externals/joblib/parallel.py:547: UserWarning: Multiprocessing-backed parallel loops cannot be nested, setting n_jobs=1
#   **self._backend_args)
# /home/rocket/anaconda2/lib/python2.7/site-packages/sklearn/externals/joblib/parallel.py:547: UserWarning: Multiprocessing-backed parallel loops cannot be nested, setting n_jobs=1
#   **self._backend_args)
# /home/rocket/anaconda2/lib/python2.7/site-packages/sklearn/externals/joblib/parallel.py:547: UserWarning: Multiprocessing-backed parallel loops cannot be nested, setting n_jobs=1
#   **self._backend_args)
# /home/rocket/anaconda2/lib/python2.7/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /home/rocket/anaconda2/lib/python2.7/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /home/rocket/anaconda2/lib/python2.7/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /home/rocket/anaconda2/lib/python2.7/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# Best parameters set found on development set:
# {'C': 1}
# Grid scores on development set:
# 0.704 (+/-0.067) for {'C': 1}
# 0.703 (+/-0.054) for {'C': 10}
# 0.703 (+/-0.052) for {'C': 100}
#
# Detailed classification report:
#
# The model is trained on the full development set.
# The scores are computed on the full evaluation set.
#
#              precision    recall  f1-score   support
#
#           0       0.78      0.76      0.77       211
#           1       0.88      0.88      0.88       127
#           2       0.76      0.78      0.77       142
#
# avg / total       0.80      0.80      0.80       480
#
#
# # Tuning hyper-parameters for recall_macro
# /home/rocket/anaconda2/lib/python2.7/site-packages/sklearn/externals/joblib/parallel.py:547: UserWarning: Multiprocessing-backed parallel loops cannot be nested, setting n_jobs=1
#   **self._backend_args)
# /home/rocket/anaconda2/lib/python2.7/site-packages/sklearn/externals/joblib/parallel.py:547: UserWarning: Multiprocessing-backed parallel loops cannot be nested, setting n_jobs=1
#   **self._backend_args)
# /home/rocket/anaconda2/lib/python2.7/site-packages/sklearn/externals/joblib/parallel.py:547: UserWarning: Multiprocessing-backed parallel loops cannot be nested, setting n_jobs=1
#   **self._backend_args)
# /home/rocket/anaconda2/lib/python2.7/site-packages/sklearn/externals/joblib/parallel.py:547: UserWarning: Multiprocessing-backed parallel loops cannot be nested, setting n_jobs=1
#   **self._backend_args)
# Best parameters set found on development set:
# {'C': 1}
# Grid scores on development set:
# 0.696 (+/-0.094) for {'C': 1}
# 0.694 (+/-0.083) for {'C': 10}
# 0.690 (+/-0.085) for {'C': 100}
#
# Detailed classification report:
#
# The model is trained on the full development set.
# The scores are computed on the full evaluation set.
#
#              precision    recall  f1-score   support
#
#           0       0.78      0.76      0.77       211
#           1       0.88      0.88      0.88       127
#           2       0.76      0.78      0.77       142
#
# avg / total       0.80      0.80      0.80       480

# %% [markdown]
# # Poly Kernel Grid Search

# %%
tuned_parameters = [{'C': [1, 10, 100],
                     'degree': [1, 2, 3, 4],
                     'decision_function_shape': ['ovo', 'ovr']}]

for score in scores:
    plt.clf()
    print("# Tuning hyper-parameters for %s" % score)

    clf = GridSearchCV(svm.SVC(kernel='poly'), tuned_parameters, cv=5, verbose=0, scoring=score, n_jobs=4)
    clf.fit(X, y)

    plot_learning_curve(clf, score, X, y, ylim=None, cv=cv, n_jobs=4).show()

    print("Best parameters set found on development set:")
    print(clf.best_params_)
    print("Grid scores on development set:")
    means = clf.cv_results_['mean_test_score']
    stds = clf.cv_results_['std_test_score']
    for mean, std, params in zip(means, stds, clf.cv_results_['params']):
        print("%0.3f (+/-%0.03f) for %r"
              % (mean, std * 2, params))
    print

    print("Detailed classification report:")
    print
    print("The model is trained on the full development set.")
    print("The scores are computed on the full evaluation set.")
    print
    y_true, y_pred = y, clf.predict(X)
    print(classification_report(y_true, y_pred))
    print
# Out:
# # Tuning hyper-parameters for accuracy
# /home/rocket/anaconda2/lib/python2.7/site-packages/sklearn/externals/joblib/parallel.py:547: UserWarning: Multiprocessing-backed parallel loops cannot be nested, setting n_jobs=1
#   **self._backend_args)
# /home/rocket/anaconda2/lib/python2.7/site-packages/sklearn/externals/joblib/parallel.py:547: UserWarning: Multiprocessing-backed parallel loops cannot be nested, setting n_jobs=1
#   **self._backend_args)
# /home/rocket/anaconda2/lib/python2.7/site-packages/sklearn/externals/joblib/parallel.py:547: UserWarning: Multiprocessing-backed parallel loops cannot be nested, setting n_jobs=1
#   **self._backend_args)
# /home/rocket/anaconda2/lib/python2.7/site-packages/sklearn/externals/joblib/parallel.py:547: UserWarning: Multiprocessing-backed parallel loops cannot be nested, setting n_jobs=1
#   **self._backend_args)
# Best parameters set found on development set:
# {'C': 1, 'decision_function_shape': 'ovo', 'degree': 1}
# Grid scores on development set:
# 0.702 (+/-0.035) for {'C': 1, 'decision_function_shape': 'ovo', 'degree': 1}
# 0.463 (+/-0.046) for {'C': 1, 'decision_function_shape': 'ovo', 'degree': 2}
# 0.633 (+/-0.117) for {'C': 1, 'decision_function_shape': 'ovo', 'degree': 3}
# 0.521 (+/-0.099) for {'C': 1, 'decision_function_shape': 'ovo', 'degree': 4}
# 0.702 (+/-0.035) for {'C': 1, 'decision_function_shape': 'ovr', 'degree': 1}
# 0.463 (+/-0.046) for {'C': 1, 'decision_function_shape': 'ovr', 'degree': 2}
# 0.633 (+/-0.117) for {'C': 1, 'decision_function_shape': 'ovr', 'degree': 3}
# 0.521 (+/-0.099) for {'C': 1, 'decision_function_shape': 'ovr', 'degree': 4}
# 0.679 (+/-0.054) for {'C': 10, 'decision_function_shape': 'ovo', 'degree': 1}
# 0.456 (+/-0.044) for {'C': 10, 'decision_function_shape': 'ovo', 'degree': 2}
# 0.642 (+/-0.144) for {'C': 10, 'decision_function_shape': 'ovo', 'degree': 3}
# 0.512 (+/-0.093) for {'C': 10, 'decision_function_shape': 'ovo', 'degree': 4}
# 0.679 (+/-0.054) for {'C': 10, 'decision_function_shape': 'ovr', 'degree': 1}
# 0.456 (+/-0.044) for {'C': 10, 'decision_function_shape': 'ovr', 'degree': 2}
# 0.642 (+/-0.144) for {'C': 10, 'decision_function_shape': 'ovr', 'degree': 3}
# 0.512 (+/-0.093) for {'C': 10, 'decision_function_shape': 'ovr', 'degree': 4}
# 0.681 (+/-0.050) for {'C': 100, 'decision_function_shape': 'ovo', 'degree': 1}
# 0.454 (+/-0.144) for {'C': 100, 'decision_function_shape': 'ovo', 'degree': 2}
# 0.650 (+/-0.128) for {'C': 100, 'decision_function_shape': 'ovo', 'degree': 3}
# 0.512 (+/-0.114) for {'C': 100, 'decision_function_shape': 'ovo', 'degree': 4}
# 0.681 (+/-0.050) for {'C': 100, 'decision_function_shape': 'ovr', 'degree': 1}
# 0.454 (+/-0.144) for {'C': 100, 'decision_function_shape': 'ovr', 'degree': 2}
# 0.650 (+/-0.128) for {'C': 100, 'decision_function_shape': 'ovr', 'degree': 3}
# 0.512 (+/-0.114) for {'C': 100, 'decision_function_shape': 'ovr', 'degree': 4}
#
# Detailed classification report:
#
# The model is trained on the full development set.
# The scores are computed on the full evaluation set.
#
#              precision    recall  f1-score   support
#
#           0       0.77      0.73      0.75       211
#           1       0.84      0.88      0.86       127
#           2       0.75      0.77      0.76       142
#
# avg / total       0.78      0.78      0.78       480
#
#
# # Tuning hyper-parameters for precision_macro
# /home/rocket/anaconda2/lib/python2.7/site-packages/sklearn/externals/joblib/parallel.py:547: UserWarning: Multiprocessing-backed parallel loops cannot be nested, setting n_jobs=1
#   **self._backend_args)
# /home/rocket/anaconda2/lib/python2.7/site-packages/sklearn/externals/joblib/parallel.py:547: UserWarning: Multiprocessing-backed parallel loops cannot be nested, setting n_jobs=1
#   **self._backend_args)
# /home/rocket/anaconda2/lib/python2.7/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /home/rocket/anaconda2/lib/python2.7/site-packages/sklearn/externals/joblib/parallel.py:547: UserWarning: Multiprocessing-backed parallel loops cannot be nested, setting n_jobs=1
#   **self._backend_args)
# /home/rocket/anaconda2/lib/python2.7/site-packages/sklearn/externals/joblib/parallel.py:547: UserWarning: Multiprocessing-backed parallel loops cannot be nested, setting n_jobs=1
#   **self._backend_args)
# /home/rocket/anaconda2/lib/python2.7/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /home/rocket/anaconda2/lib/python2.7/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# Best parameters set found on development set:
# {'C': 1, 'decision_function_shape': 'ovo', 'degree': 1}
# Grid scores on development set:
# 0.719 (+/-0.043) for {'C': 1, 'decision_function_shape': 'ovo', 'degree': 1}
# 0.379 (+/-0.102) for {'C': 1, 'decision_function_shape': 'ovo', 'degree': 2}
# 0.709 (+/-0.104) for {'C': 1, 'decision_function_shape': 'ovo', 'degree': 3}
# 0.498 (+/-0.221) for {'C': 1, 'decision_function_shape': 'ovo', 'degree': 4}
# 0.719 (+/-0.043) for {'C': 1, 'decision_function_shape': 'ovr', 'degree': 1}
# 0.379 (+/-0.102) for {'C': 1, 'decision_function_shape': 'ovr', 'degree': 2}
# 0.709 (+/-0.104) for {'C': 1, 'decision_function_shape': 'ovr', 'degree': 3}
# 0.498 (+/-0.221) for {'C': 1, 'decision_function_shape': 'ovr', 'degree': 4}
# 0.700 (+/-0.061) for {'C': 10, 'decision_function_shape': 'ovo', 'degree': 1}
# 0.421 (+/-0.094) for {'C': 10, 'decision_function_shape': 'ovo', 'degree': 2}
# 0.682 (+/-0.140) for {'C': 10, 'decision_function_shape': 'ovo', 'degree': 3}
# 0.504 (+/-0.181) for {'C': 10, 'decision_function_shape': 'ovo', 'degree': 4}
# 0.700 (+/-0.061) for {'C': 10, 'decision_function_shape': 'ovr', 'degree': 1}
# 0.421 (+/-0.094) for {'C': 10, 'decision_function_shape': 'ovr', 'degree': 2}
# 0.682 (+/-0.140) for {'C': 10, 'decision_function_shape': 'ovr', 'degree': 3}
# 0.504 (+/-0.181) for {'C': 10, 'decision_function_shape': 'ovr', 'degree': 4}
# 0.704 (+/-0.062) for {'C': 100, 'decision_function_shape': 'ovo', 'degree': 1}
# 0.419 (+/-0.152) for {'C': 100, 'decision_function_shape': 'ovo', 'degree': 2}
# 0.701 (+/-0.132) for {'C': 100, 'decision_function_shape': 'ovo', 'degree': 3}
# 0.503 (+/-0.194) for {'C': 100, 'decision_function_shape': 'ovo', 'degree': 4}
# 0.704 (+/-0.062) for {'C': 100, 'decision_function_shape': 'ovr', 'degree': 1}
# 0.419 (+/-0.152) for {'C': 100, 'decision_function_shape': 'ovr', 'degree': 2}
# 0.701 (+/-0.132) for {'C': 100, 'decision_function_shape': 'ovr', 'degree': 3}
# 0.503 (+/-0.194) for {'C': 100, 'decision_function_shape': 'ovr', 'degree': 4}
#
# Detailed classification report:
#
# The model is trained on the full development set.
# The scores are computed on the full evaluation set.
#
#              precision    recall  f1-score   support
#
#           0       0.77      0.73      0.75       211
#           1       0.84      0.88      0.86       127
#           2       0.75      0.77      0.76       142
#
# avg / total       0.78      0.78      0.78       480
#
#
# # Tuning hyper-parameters for recall_macro
# /home/rocket/anaconda2/lib/python2.7/site-packages/sklearn/externals/joblib/parallel.py:547: UserWarning: Multiprocessing-backed parallel loops cannot be nested, setting n_jobs=1
#   **self._backend_args)
# /home/rocket/anaconda2/lib/python2.7/site-packages/sklearn/externals/joblib/parallel.py:547: UserWarning: Multiprocessing-backed parallel loops cannot be nested, setting n_jobs=1
#   **self._backend_args)
# /home/rocket/anaconda2/lib/python2.7/site-packages/sklearn/externals/joblib/parallel.py:547: UserWarning: Multiprocessing-backed parallel loops cannot be nested, setting n_jobs=1
#   **self._backend_args)
# /home/rocket/anaconda2/lib/python2.7/site-packages/sklearn/externals/joblib/parallel.py:547: UserWarning: Multiprocessing-backed parallel loops cannot be nested, setting n_jobs=1
#   **self._backend_args)
# Best parameters set found on development set:
# {'C': 1, 'decision_function_shape': 'ovo', 'degree': 1}
# Grid scores on development set:
# 0.719 (+/-0.039) for {'C': 1, 'decision_function_shape': 'ovo', 'degree': 1}
# 0.400 (+/-0.053) for {'C': 1, 'decision_function_shape': 'ovo', 'degree': 2}
# 0.609 (+/-0.130) for {'C': 1, 'decision_function_shape': 'ovo', 'degree': 3}
# 0.456 (+/-0.098) for {'C': 1, 'decision_function_shape': 'ovo', 'degree': 4}
# 0.719 (+/-0.039) for {'C': 1, 'decision_function_shape': 'ovr', 'degree': 1}
# 0.400 (+/-0.053) for {'C': 1, 'decision_function_shape': 'ovr', 'degree': 2}
# 0.609 (+/-0.130) for {'C': 1, 'decision_function_shape': 'ovr', 'degree': 3}
# 0.456 (+/-0.098) for {'C': 1, 'decision_function_shape': 'ovr', 'degree': 4}
# 0.693 (+/-0.083) for {'C': 10, 'decision_function_shape': 'ovo', 'degree': 1}
# 0.421 (+/-0.042) for {'C': 10, 'decision_function_shape': 'ovo', 'degree': 2}
# 0.647 (+/-0.153) for {'C': 10, 'decision_function_shape': 'ovo', 'degree': 3}
# 0.472 (+/-0.113) for {'C': 10, 'decision_function_shape': 'ovo', 'degree': 4}
# 0.693 (+/-0.083) for {'C': 10, 'decision_function_shape': 'ovr', 'degree': 1}
# 0.421 (+/-0.042) for {'C': 10, 'decision_function_shape': 'ovr', 'degree': 2}
# 0.647 (+/-0.153) for {'C': 10, 'decision_function_shape': 'ovr', 'degree': 3}
# 0.472 (+/-0.113) for {'C': 10, 'decision_function_shape': 'ovr', 'degree': 4}
# 0.693 (+/-0.076) for {'C': 100, 'decision_function_shape': 'ovo', 'degree': 1}
# 0.419 (+/-0.121) for {'C': 100, 'decision_function_shape': 'ovo', 'degree': 2}
# 0.648 (+/-0.133) for {'C': 100, 'decision_function_shape': 'ovo', 'degree': 3}
# 0.473 (+/-0.130) for {'C': 100, 'decision_function_shape': 'ovo', 'degree': 4}
# 0.693 (+/-0.076) for {'C': 100, 'decision_function_shape': 'ovr', 'degree': 1}
# 0.419 (+/-0.121) for {'C': 100, 'decision_function_shape': 'ovr', 'degree': 2}
# 0.648 (+/-0.133) for {'C': 100, 'decision_function_shape': 'ovr', 'degree': 3}
# 0.473 (+/-0.130) for {'C': 100, 'decision_function_shape': 'ovr', 'degree': 4}
#
# Detailed classification report:
#
# The model is trained on the full development set.
# The scores are computed on the full evaluation set.
#
#              precision    recall  f1-score   support
#
#           0       0.77      0.73      0.75       211
#           1       0.84      0.88      0.86       127
#           2       0.75      0.77      0.76       142
#
# avg / total       0.78      0.78      0.78       480

# %% [markdown]
# # Sigmoid Kernel

# %%
tuned_parameters = [{'gamma': [1, 1e-2, 1e-3, 1e-4],
                     'C': [1, 10, 100],
                     'decision_function_shape': ['ovo', 'ovr']}]
for score in scores:
    plt.clf()
    print("# Tuning hyper-parameters for %s" % score)

    clf = GridSearchCV(svm.SVC(kernel='sigmoid'), tuned_parameters, cv=5, verbose=0, scoring=score, n_jobs=4)
    clf.fit(X, y)

    plot_learning_curve(clf, score, X, y, ylim=None, cv=cv, n_jobs=4).show()

    print("Best parameters set found on development set:")
    print(clf.best_params_)
    print("Grid scores on development set:")
    means = clf.cv_results_['mean_test_score']
    stds = clf.cv_results_['std_test_score']
    for mean, std, params in zip(means, stds, clf.cv_results_['params']):
        print("%0.3f (+/-%0.03f) for %r"
              % (mean, std * 2, params))
    print

    print("Detailed classification report:")
    print
    print("The model is trained on the full development set.")
    print("The scores are computed on the full evaluation set.")
    print
    y_true, y_pred = y, clf.predict(X)
    print(classification_report(y_true, y_pred))
    print
# Out:
# # Tuning hyper-parameters for accuracy
# /home/rocket/anaconda2/lib/python2.7/site-packages/sklearn/externals/joblib/parallel.py:547: UserWarning: Multiprocessing-backed parallel loops cannot be nested, setting n_jobs=1
#   **self._backend_args)
# /home/rocket/anaconda2/lib/python2.7/site-packages/sklearn/externals/joblib/parallel.py:547: UserWarning: Multiprocessing-backed parallel loops cannot be nested, setting n_jobs=1
#   **self._backend_args)
# /home/rocket/anaconda2/lib/python2.7/site-packages/sklearn/externals/joblib/parallel.py:547: UserWarning: Multiprocessing-backed parallel loops cannot be nested, setting n_jobs=1
#   **self._backend_args)
# /home/rocket/anaconda2/lib/python2.7/site-packages/sklearn/externals/joblib/parallel.py:547: UserWarning: Multiprocessing-backed parallel loops cannot be nested, setting n_jobs=1
#   **self._backend_args)
# Best parameters set found on development set:
# {'C': 10, 'decision_function_shape': 'ovo', 'gamma': 0.01}
# Grid scores on development set:
# 0.610 (+/-0.109) for {'C': 1, 'decision_function_shape': 'ovo', 'gamma': 1}
# 0.677 (+/-0.099) for {'C': 1, 'decision_function_shape': 'ovo', 'gamma': 0.01}
# 0.440 (+/-0.007) for {'C': 1, 'decision_function_shape': 'ovo', 'gamma': 0.001}
# 0.440 (+/-0.007) for {'C': 1, 'decision_function_shape': 'ovo', 'gamma': 0.0001}
# 0.610 (+/-0.109) for {'C': 1, 'decision_function_shape': 'ovr', 'gamma': 1}
# 0.677 (+/-0.099) for {'C': 1, 'decision_function_shape': 'ovr', 'gamma': 0.01}
# 0.440 (+/-0.007) for {'C': 1, 'decision_function_shape': 'ovr', 'gamma': 0.001}
# 0.440 (+/-0.007) for {'C': 1, 'decision_function_shape': 'ovr', 'gamma': 0.0001}
# 0.617 (+/-0.069) for {'C': 10, 'decision_function_shape': 'ovo', 'gamma': 1}
# 0.688 (+/-0.054) for {'C': 10, 'decision_function_shape': 'ovo', 'gamma': 0.01}
# 0.677 (+/-0.099) for {'C': 10, 'decision_function_shape': 'ovo', 'gamma': 0.001}
# 0.440 (+/-0.007) for {'C': 10, 'decision_function_shape': 'ovo', 'gamma': 0.0001}
# 0.617 (+/-0.069) for {'C': 10, 'decision_function_shape': 'ovr', 'gamma': 1}
# 0.688 (+/-0.054) for {'C': 10, 'decision_function_shape': 'ovr', 'gamma': 0.01}
# 0.677 (+/-0.099) for {'C': 10, 'decision_function_shape': 'ovr', 'gamma': 0.001}
# 0.440 (+/-0.007) for {'C': 10, 'decision_function_shape': 'ovr', 'gamma': 0.0001}
# 0.631 (+/-0.037) for {'C': 100, 'decision_function_shape': 'ovo', 'gamma': 1}
# 0.688 (+/-0.080) for {'C': 100, 'decision_function_shape': 'ovo', 'gamma': 0.01}
# 0.685 (+/-0.062) for {'C': 100, 'decision_function_shape': 'ovo', 'gamma': 0.001}
# 0.677 (+/-0.099) for {'C': 100, 'decision_function_shape': 'ovo', 'gamma': 0.0001}
# 0.631 (+/-0.037) for {'C': 100, 'decision_function_shape': 'ovr', 'gamma': 1}
# 0.688 (+/-0.080) for {'C': 100, 'decision_function_shape': 'ovr', 'gamma': 0.01}
# 0.685 (+/-0.062) for {'C': 100, 'decision_function_shape': 'ovr', 'gamma': 0.001}
# 0.677 (+/-0.099) for {'C': 100, 'decision_function_shape': 'ovr', 'gamma': 0.0001}
#
# Detailed classification report:
#
# The model is trained on the full development set.
# The scores are computed on the full evaluation set.
#
#              precision    recall  f1-score   support
#
#           0       0.76      0.73      0.74       211
#           1       0.84      0.87      0.86       127
#           2       0.74      0.77      0.75       142
#
# avg / total       0.78      0.78      0.78       480
#
#
# # Tuning hyper-parameters for precision_macro
# /home/rocket/anaconda2/lib/python2.7/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /home/rocket/anaconda2/lib/python2.7/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /home/rocket/anaconda2/lib/python2.7/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /home/rocket/anaconda2/lib/python2.7/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /home/rocket/anaconda2/lib/python2.7/site-packages/sklearn/externals/joblib/parallel.py:547: UserWarning: Multiprocessing-backed parallel loops cannot be nested, setting n_jobs=1
#   **self._backend_args)
# /home/rocket/anaconda2/lib/python2.7/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /home/rocket/anaconda2/lib/python2.7/site-packages/sklearn/externals/joblib/parallel.py:547: UserWarning: Multiprocessing-backed parallel loops cannot be nested, setting n_jobs=1
#   **self._backend_args)
# /home/rocket/anaconda2/lib/python2.7/site-packages/sklearn/externals/joblib/parallel.py:547: UserWarning: Multiprocessing-backed parallel loops cannot be nested, setting n_jobs=1
#   **self._backend_args)
# /home/rocket/anaconda2/lib/python2.7/site-packages/sklearn/externals/joblib/parallel.py:547: UserWarning: Multiprocessing-backed parallel loops cannot be nested, setting n_jobs=1
#   **self._backend_args)
# /home/rocket/anaconda2/lib/python2.7/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /home/rocket/anaconda2/lib/python2.7/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /home/rocket/anaconda2/lib/python2.7/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# Best parameters set found on development set:
# {'C': 100, 'decision_function_shape': 'ovo', 'gamma': 0.01}
# Grid scores on development set:
# 0.642 (+/-0.125) for {'C': 1, 'decision_function_shape': 'ovo', 'gamma': 1}
# 0.704 (+/-0.083) for {'C': 1, 'decision_function_shape': 'ovo', 'gamma': 0.01}
# 0.147 (+/-0.002) for {'C': 1, 'decision_function_shape': 'ovo', 'gamma': 0.001}
# 0.147 (+/-0.002) for {'C': 1, 'decision_function_shape': 'ovo', 'gamma': 0.0001}
# 0.642 (+/-0.125) for {'C': 1, 'decision_function_shape': 'ovr', 'gamma': 1}
# 0.704 (+/-0.083) for {'C': 1, 'decision_function_shape': 'ovr', 'gamma': 0.01}
# 0.147 (+/-0.002) for {'C': 1, 'decision_function_shape': 'ovr', 'gamma': 0.001}
# 0.147 (+/-0.002) for {'C': 1, 'decision_function_shape': 'ovr', 'gamma': 0.0001}
# 0.634 (+/-0.087) for {'C': 10, 'decision_function_shape': 'ovo', 'gamma': 1}
# 0.702 (+/-0.063) for {'C': 10, 'decision_function_shape': 'ovo', 'gamma': 0.01}
# 0.704 (+/-0.083) for {'C': 10, 'decision_function_shape': 'ovo', 'gamma': 0.001}
# 0.147 (+/-0.002) for {'C': 10, 'decision_function_shape': 'ovo', 'gamma': 0.0001}
# 0.634 (+/-0.087) for {'C': 10, 'decision_function_shape': 'ovr', 'gamma': 1}
# 0.702 (+/-0.063) for {'C': 10, 'decision_function_shape': 'ovr', 'gamma': 0.01}
# 0.704 (+/-0.083) for {'C': 10, 'decision_function_shape': 'ovr', 'gamma': 0.001}
# 0.147 (+/-0.002) for {'C': 10, 'decision_function_shape': 'ovr', 'gamma': 0.0001}
# 0.649 (+/-0.065) for {'C': 100, 'decision_function_shape': 'ovo', 'gamma': 1}
# 0.713 (+/-0.092) for {'C': 100, 'decision_function_shape': 'ovo', 'gamma': 0.01}
# 0.702 (+/-0.069) for {'C': 100, 'decision_function_shape': 'ovo', 'gamma': 0.001}
# 0.704 (+/-0.083) for {'C': 100, 'decision_function_shape': 'ovo', 'gamma': 0.0001}
# 0.649 (+/-0.065) for {'C': 100, 'decision_function_shape': 'ovr', 'gamma': 1}
# 0.713 (+/-0.092) for {'C': 100, 'decision_function_shape': 'ovr', 'gamma': 0.01}
# 0.702 (+/-0.069) for {'C': 100, 'decision_function_shape': 'ovr', 'gamma': 0.001}
# 0.704 (+/-0.083) for {'C': 100, 'decision_function_shape': 'ovr', 'gamma': 0.0001}
#
# Detailed classification report:
#
# The model is trained on the full development set.
# The scores are computed on the full evaluation set.
#
#              precision    recall  f1-score   support
#
#           0       0.74      0.74      0.74       211
#           1       0.84      0.88      0.86       127
#           2       0.74      0.71      0.72       142
#
# avg / total       0.77      0.77      0.77       480
#
#
# # Tuning hyper-parameters for recall_macro
# /home/rocket/anaconda2/lib/python2.7/site-packages/sklearn/externals/joblib/parallel.py:547: UserWarning: Multiprocessing-backed parallel loops cannot be nested, setting n_jobs=1
#   **self._backend_args)
# /home/rocket/anaconda2/lib/python2.7/site-packages/sklearn/externals/joblib/parallel.py:547: UserWarning: Multiprocessing-backed parallel loops cannot be nested, setting n_jobs=1
#   **self._backend_args)
# /home/rocket/anaconda2/lib/python2.7/site-packages/sklearn/externals/joblib/parallel.py:547: UserWarning: Multiprocessing-backed parallel loops cannot be nested, setting n_jobs=1
#   **self._backend_args)
# /home/rocket/anaconda2/lib/python2.7/site-packages/sklearn/externals/joblib/parallel.py:547: UserWarning: Multiprocessing-backed parallel loops cannot be nested, setting n_jobs=1
#   **self._backend_args)
# Best parameters set found on development set:
# {'C': 100, 'decision_function_shape': 'ovo', 'gamma': 0.001}
# Grid scores on development set:
# 0.617 (+/-0.134) for {'C': 1, 'decision_function_shape': 'ovo', 'gamma': 1}
# 0.698 (+/-0.066) for {'C': 1, 'decision_function_shape': 'ovo', 'gamma': 0.01}
# 0.333 (+/-0.000) for {'C': 1, 'decision_function_shape': 'ovo', 'gamma': 0.001}
# 0.333 (+/-0.000) for {'C': 1, 'decision_function_shape': 'ovo', 'gamma': 0.0001}
# 0.617 (+/-0.134) for {'C': 1, 'decision_function_shape': 'ovr', 'gamma': 1}
# 0.698 (+/-0.066) for {'C': 1, 'decision_function_shape': 'ovr', 'gamma': 0.01}
# 0.333 (+/-0.000) for {'C': 1, 'decision_function_shape': 'ovr', 'gamma': 0.001}
# 0.333 (+/-0.000) for {'C': 1, 'decision_function_shape': 'ovr', 'gamma': 0.0001}
# 0.625 (+/-0.053) for {'C': 10, 'decision_function_shape': 'ovo', 'gamma': 1}
# 0.702 (+/-0.066) for {'C': 10, 'decision_function_shape': 'ovo', 'gamma': 0.01}
# 0.698 (+/-0.066) for {'C': 10, 'decision_function_shape': 'ovo', 'gamma': 0.001}
# 0.333 (+/-0.000) for {'C': 10, 'decision_function_shape': 'ovo', 'gamma': 0.0001}
# 0.625 (+/-0.053) for {'C': 10, 'decision_function_shape': 'ovr', 'gamma': 1}
# 0.702 (+/-0.066) for {'C': 10, 'decision_function_shape': 'ovr', 'gamma': 0.01}
# 0.698 (+/-0.066) for {'C': 10, 'decision_function_shape': 'ovr', 'gamma': 0.001}
# 0.333 (+/-0.000) for {'C': 10, 'decision_function_shape': 'ovr', 'gamma': 0.0001}
# 0.643 (+/-0.036) for {'C': 100, 'decision_function_shape': 'ovo', 'gamma': 1}
# 0.697 (+/-0.100) for {'C': 100, 'decision_function_shape': 'ovo', 'gamma': 0.01}
# 0.702 (+/-0.077) for {'C': 100, 'decision_function_shape': 'ovo', 'gamma': 0.001}
# 0.698 (+/-0.066) for {'C': 100, 'decision_function_shape': 'ovo', 'gamma': 0.0001}
# 0.643 (+/-0.036) for {'C': 100, 'decision_function_shape': 'ovr', 'gamma': 1}
# 0.697 (+/-0.100) for {'C': 100, 'decision_function_shape': 'ovr', 'gamma': 0.01}
# 0.702 (+/-0.077) for {'C': 100, 'decision_function_shape': 'ovr', 'gamma': 0.001}
# 0.698 (+/-0.066) for {'C': 100, 'decision_function_shape': 'ovr', 'gamma': 0.0001}
#
# Detailed classification report:
#
# The model is trained on the full development set.
# The scores are computed on the full evaluation set.
#
#              precision    recall  f1-score   support
#
#           0       0.76      0.73      0.74       211
#           1       0.84      0.87      0.85       127
#           2       0.74      0.77      0.76       142
#
# avg / total       0.78      0.78      0.78       480
